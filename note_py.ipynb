# %% [markdown]
# <a href="https://colab.research.google.com/github/bayashi-cl/statistical-learning/blob/working/note_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pythonのノート

# %%
import sys
print(sys.version)
# Out:
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## インストール済みパッケージ

# %%
# !pip list

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

sns.set()

# %%
ad = pd.read_csv("https://www.statlearning.com/s/Advertising.csv", index_col=0)
print(ad.head())
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
# sns.set_theme(style="white", palette=None)
sns.pairplot(
  ad,
  x_vars=ad.columns[:-1],
  y_vars=ad.columns[-1:],
  kind="reg",
  height=4,
)
plt.show()

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("5N9V07EIfIg")

# %% [markdown]
# pythonでもPDFの表示は無理そう

# %%
# !curl -OL https://www.statlearning.com/s/Figures-Chapters-1-6.zip
# !unzip Figures-Chapters-1-6.zip

# %%
from IPython.display import display_pdf
import pathlib
# target = pathlib.Path("/content/Figures - Chapters 1-6/Chapter1/1_1.pdf")
filename = "./1_1.pdf"
with open(filename, "rb") as f:
  display_pdf(f.read())  
# display_pdf(target.read_bytes(), raw=True)

# %%
# !pip install wand
# Out:
# ...
#      |████████████████████████████████| 139 kB 5.0 MB/s
# ...

# %%
# !which poppler

# %%
from wand.image import Image as WImage
img = WImage(filename='./1_1.pdf')
img
# Out:
# ---------------------------------------------------------------------------
# PolicyError                               Traceback (most recent call last)
# <ipython-input-16-27bbbed5bf8d> in <module>()
#       1 from wand.image import Image as WImage
# ----> 2 img = WImage(filename='./1_1.pdf')
#       3 img
#
# /usr/local/lib/python3.7/dist-packages/wand/image.py in __init__(self, image, blob, file, filename, pseudo, background, colorspace, depth, extract, format, height, interlace, resolution, sampling_factors, units, width)
#    9142                     self.read(blob=blob)
#    9143                 elif filename is not None:
# -> 9144                     self.read(filename=filename)
#    9145                 # clear the wand format, otherwise any subsequent call to
#    9146                 # MagickGetImageBlob will silently change the image to this
#
# ...

# %%
fi = pathlib.Path("./1_1.pdf")
print(fi.exists())
# Out:
# True
