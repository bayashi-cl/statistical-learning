# %% [markdown]
# <a href="https://colab.research.google.com/github/bayashi-cl/statistical-learning/blob/working/memo_r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls()
# rm(g)
# Out:
# [1] "ad"

# %%
install.packages("ISLR2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ISLR2)
library(ggplot2)

# %%
download.file("https://www.statlearning.com/s/Advertising.csv", "Advertising.csv")
ad <- read.csv("Advertising.csv", stringsAsFactors = T, row.names = "X")

# %%
head(ad)
# Out:
#   TV    radio newspaper sales
# 1 230.1 37.8  69.2      22.1
# 2  44.5 39.3  45.1      10.4
# 3  17.2 45.9  69.3       9.3
# 4 151.5 41.3  58.5      18.5
# 5 180.8 10.8  58.4      12.9
# 6   8.7 48.9  75.0       7.2

# %%
g1 <- ggplot(ad, aes(x = TV, y = sales)) + geom_point()
plot(g1)
# Out:
# plot without title

# %%
g2 <- ggplot(ad, aes(x = newspaper, y = sales)) + geom_point()
plot(g2)
# Out:
# plot without title

# %%
g3 <- ggplot(ad, aes(x = radio, y = sales)) + geom_point()
plot(g3)
# Out:
# plot without title

# %%
getwd()
# Out:
# [1] "/content"

# %%
IRdisplay::display_html('<iframe width="560" height="315" src="https://www.youtube.com/embed/5N9V07EIfIg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/5N9V07EIfIg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
download.file("https://www.statlearning.com/s/Figures-Chapters-1-6.zip", destfile = "figure.zip")
unzip("./figure.zip")

# %%
library(IRdisplay)
# pdfの表示はむりっぽい
display_pdf(file = "/content/Figures - Chapters 1-6/Chapter1/1_2.pdf", width = 400, height = 300)
